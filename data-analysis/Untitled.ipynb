# %%
# Out:
# ['Kulturpalast', 'confort', 'Kaloian', 'agusto', 'hornillos', 'nachdenken', 'mogelijkheden', '4°', 'spare', '非常好｡', 'ligging', 'einem', '편입니다', 'projection', 'Luba', 'freie', 'treid', 'spotlessly', 'Atmosphere', 'ONLY', 'Babybett', 'κλείσιμο', 'misma', 'mont', 'подреден', 'illiterate', 'apartment..booked', 'significant', 'bases', '그다지', 'metro/bus', 'freundlicher', 'streets', 'обойти', 'nevskij', 'Unkomplizierter', 'ridiculously', 'stazione', 'reccomendations', '部屋はとてもかわいく快適で､ｾﾝﾀｰからも近く､素晴らしいところでした｡', 'mentioning', 'facades', 'qualunque', 'комплектации', '古老和现代相互融合', 'Appartamentino', 'effocient', '윗층이예요', 'Lokation', 'Fragen', 'комуникирал', 'automatic', 'atention', 'partner', 'Walkable', 'centro.muy', 'всегда', 'Лучше', 'divide', 'passionate', 'Zoltán', 'sécurisé', 'reiste', 'Pretty', 'voeten', 'vity', 'deshumidificador', 'strettamente', 'itslef', 'rigtig', 'postpone', 'gratuito', 'stimmt', 'train/bed', 'prise', 'Cela', 'Più', 'zorgen', 'Πρόκειται', 'softer', 'Described', 'Цар', '1,
# ...
